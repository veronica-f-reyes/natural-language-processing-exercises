# %% [markdown]
# # Data Acquisition / Web Scraping Exercises
# ***
#
# ## Exercises
#
# - By the end of this exercise, you should have a file named acquire.py that contains the specified functions.
# - If you wish, you may break your work into separate files for each website (e.g. acquire_codeup_blog.py and acquire_news_articles.py), but the end function should be present in acquire.py
# (that is, acquire.py should import get_blog_articles from the acquire_codeup_blog module.)

# %% [markdown]
# #### 1.) Codeup Blog Articles
#
# Scrape the article text from the following pages:
#
# - https://codeup.com/data-science/codeups-data-science-career-accelerator-is-here/
# - https://codeup.com/data-science/data-science-myths/
# - https://codeup.com/data-science/data-science-vs-data-analytics-whats-the-difference/
# - https://codeup.com/data-science/10-tips-to-crush-it-at-the-sa-tech-job-fair/
# - https://codeup.com/data-science/competitor-bootcamps-are-closing-is-the-model-in-danger/

# %%
import requests
from bs4 import BeautifulSoup 
import pandas as pd

# %%
response = requests.get('https://codeup.com/data-science/codeups-data-science-career-accelerator-is-here/', headers={'user-agent': 'Codeup DS Germain'})
soup = BeautifulSoup(response.text)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="https://codeup.com/xmlrpc.php" rel="pingback"/>
# <script type="text/javascript">
# 		document.documentElement.className = 'js';
# 	</script>
# ...

# %%
articles = soup.select('.et_pb_section.et_pb_section_0_tb_body.et_section_regular')
articles
# Out:
# [<div class="et_pb_section et_pb_section_0_tb_body et_section_regular">
#  <div class="et_pb_row et_pb_row_0_tb_body">
#  <div class="et_pb_column et_pb_column_3_4 et_pb_column_0_tb_body et_pb_css_mix_blend_mode_passthrough">
#  <div class="et_pb_module et_pb_post_title et_pb_post_title_0_tb_body et_pb_bg_layout_light et_pb_text_align_left">
# ...

# %%
article = articles[0]
article
# Out:
# <div class="et_pb_section et_pb_section_0_tb_body et_section_regular">
# <div class="et_pb_row et_pb_row_0_tb_body">
# <div class="et_pb_column et_pb_column_3_4 et_pb_column_0_tb_body et_pb_css_mix_blend_mode_passthrough">
# <div class="et_pb_module et_pb_post_title et_pb_post_title_0_tb_body et_pb_bg_layout_light et_pb_text_align_left">
# ...

# %%
#title
title  = article.select('.entry-title')[0].text
title
# Out:
# 'Codeup’s Data Science Career Accelerator is Here!'

# %%
#content
content = article.select('.et_pb_module.et_pb_post_content.et_pb_post_content_0_tb_body')[0].text
content
# Out:
# '\nThe rumors are true! The time has arrived. Codeup has officially opened applications to our new Data Science career accelerator, with only 25 seats available! This immersive program is one of a kind in San Antonio, and will help you land a job in\xa0Glassdoor’s #1 Best Job in America.\nData Science is a method of providing actionable intelligence from data.\xa0The data revolution has hit San Antonio,\xa0resulting in an explosion in Data Scientist positions\xa0across companies like USAA, Accenture, Booz Allen Hamilton, and HEB. We’ve even seen\xa0UTSA invest $70 M for a Cybersecurity Center and School of Data Science.\xa0We built a program to specifically meet the growing demands of this industry.\nOur program will be 18 weeks long, full-time, hands-on, and project-based. Our curriculum development and instruction is led by Senior Data Scientist, Maggie Giust, who has worked at HEB, Capital Group, and Rackspace, along with input from dozens of practitioners and hiring partners. Stu
# ...

# %%
# Create a function to read all articles and create a dictionary containing the title and content of each article

def parse_article(article):
    
    #title
    title  = article.select('.entry-title')[0].text
    
    #content
    content = article.select('.et_pb_module.et_pb_post_content.et_pb_post_content_0_tb_body')[0].text.strip()
    
    return {'title': title, 'content': content}

# %%
pd.DataFrame([parse_article(article) for article in articles])
# Out:
#                                                title  \
# 0  Codeup’s Data Science Career Accelerator is Here!
#
#                                              content
# 0  The rumors are true! The time has arrived. Cod...

# %%
urls = ['https://codeup.com/data-science/codeups-data-science-career-accelerator-is-here/',
        'https://codeup.com/data-science/data-science-myths/',
        'https://codeup.com/data-science/data-science-vs-data-analytics-whats-the-difference/',
        'https://codeup.com/data-science/10-tips-to-crush-it-at-the-sa-tech-job-fair/',
        'https://codeup.com/data-science/competitor-bootcamps-are-closing-is-the-model-in-danger/']

# %%
# Create a function that takes a list of websites and parses the articles from them and creates a dictionary with 
# title and content of each article

def get_blog_articles(urls):
    
    for url in urls:
        
        if url == urls[0]:
        
            response = requests.get(url, headers={'user-agent': 'Codeup DS Germain'})
            soup = BeautifulSoup(response.text)
        
            #Get the articles from the web page
            articles = soup.select('.et_pb_section.et_pb_section_0_tb_body.et_section_regular')
        
            article = articles[0]
        
            df = pd.DataFrame([parse_article(article) for article in articles])   
            
        
        else: 
            
            response = requests.get(url, headers={'user-agent': 'Codeup DS Germain'})
            soup = BeautifulSoup(response.text)
        
            #Get the articles from the web page
            articles = soup.select('.et_pb_section.et_pb_section_0_tb_body.et_section_regular')
        
            article = articles[0]  
            
            df = df.append(pd.DataFrame([parse_article(article) for article in articles]), ignore_index=True)
        
    return df

# %%
get_blog_articles(urls)
# Out:
#                                                title  \
# 0  Codeup’s Data Science Career Accelerator is Here!
# 1                                 Data Science Myths
# 2  Data Science VS Data Analytics: What’s The Dif...
# 3        10 Tips to Crush It at the SA Tech Job Fair
# 4  Competitor Bootcamps Are Closing. Is the Model...
#
#                                              content
# 0  The rumors are true! The time has arrived. Cod...
# 1  By Dimitri Antoniou and Maggie Giust\nData Sci...
# 2  By Dimitri Antoniou\nA week ago, Codeup launch...
# 3  SA Tech Job Fair\nThe third bi-annual San Anto...
# 4  Competitor Bootcamps Are Closing. Is the Model...

# %% [markdown]
# ***

# %% [markdown]
# ### 2. ) News Articles
#
# - We will now be scraping text data from inshorts.com, a website that provides a brief overview of many different topics.
#
# - Write a function that scrapes the news articles for the following topics:
#
#      - Business
#      - Sports
#      - Technology
#      - Entertainment

# %%
response_business = requests.get('https://inshorts.com/en/read/business', headers={'user-agent': 'Codeup DS Germain'})
soup = BeautifulSoup(response_business.text)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <style>
#     /* The Modal (background) */
#     .modal_contact {
#         display: none; /* Hidden by default */
#         position: fixed; /* Stay in place */
#         z-index: 8; /* Sit on top */
#         left: 0;
#         top: 0;
#         width: 100%; /* Full width */
#         height: 100%;
#         overflow: auto; /* Enable scroll if needed */
#         background-color: rgb(0,0,0); /* Fallback color */
#         background-color: rgba(0,0,0,0.4); /* Black w/ opacity */
#     }
#
#     /* Modal Content/Box */
#     .modal-content {
#         background-color: #fefefe;
#         margin: 15% auto;
#         padding: 20px !important;
#         padding-top: 0 !important;
#         /* border: 1px solid #888; */
#         text-align: center;
#         position: relative;
#         border-radius: 6px;
#     }
#
#     /* The Close Button */
#     .close {
#       left: 90%;
#       color: #aaa;
# ...

# %%
articles = soup.select('.news-card.z-depth-1')
articles
# Out:
# [<div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
#  <span content="" itemid="https://inshorts.com/en/news/indias-covaxin-may-get-who-approval-in-next-24-hours-spokesperson-1635247097874" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
#  <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
#  <span content="Kiran Khatri" itemprop="name"></span>
#  </span>
#  <span content="India's Covaxin may get WHO approval in next 24 hours: Spokesperson" itemprop="description"></span>
#  <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#  <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/10_oct/26_tue/img_1635246183818_894.jpg?" itemprop="url"/>
#  <meta content="864" itemprop="width"/>
#  <meta content="483" itemprop="height"/>
#  </span>
# ...

# %%
article = articles[0]
article
# Out:
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/indias-covaxin-may-get-who-approval-in-next-24-hours-spokesperson-1635247097874" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Kiran Khatri" itemprop="name"></span>
# </span>
# <span content="India's Covaxin may get WHO approval in next 24 hours: Spokesperson" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/10_oct/26_tue/img_1635246183818_894.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# ...

# %%
title = article.find(itemprop="description")

# %%
title['content']
# Out:
# "India's Covaxin may get WHO approval in next 24 hours: Spokesperson"

# %%
t2 = article.find('span',itemprop="headline").text
t2
# Out:
# "India's Covaxin may get WHO approval in next 24 hours: Spokesperson"

# %%
author = article.find('span', 'author').text
author
# Out:
# 'Kiran Khatri'

# %%
#content
content = article.find('div',itemprop="articleBody").text
content
# Out:
# 'A WHO technical advisory group which met on Tuesday to consider Bharat Biotech\'s COVID-19 vaccine Covaxin for emergency use listing is likely to announce its decision soon. "If all is in place and all goes well and if the committee is satisfied, we would expect a recommendation within the next 24 hours or so," WHO spokesperson Margaret Harris told reporters. '

# %%
# Create a function to read all articles and create a dictionary containing the title and content of each article

def parse_article(article, category):
    
    #title
    title  = article.find('span',itemprop="headline").text
    
    #author
    author = article.find('span', 'author').text
    
    #content
    content = article.find('div',itemprop="articleBody").text.strip()
    
    #category
    category = category
    
    
    
    return {'title': title, 'author':author, 'content': content,'category': category}

# %%
parse_article(article, 'business')
# Out:
# {'title': "India's Covaxin may get WHO approval in next 24 hours: Spokesperson",
#  'author': 'Kiran Khatri',
#  'content': 'A WHO technical advisory group which met on Tuesday to consider Bharat Biotech\'s COVID-19 vaccine Covaxin for emergency use listing is likely to announce its decision soon. "If all is in place and all goes well and if the committee is satisfied, we would expect a recommendation within the next 24 hours or so," WHO spokesperson Margaret Harris told reporters.',
#  'category': 'business'}

# %%
pd.DataFrame([parse_article(article,'business') for article in articles])
# Out:
#                                                 title             author  \
# 0   India's Covaxin may get WHO approval in next 2...       Kiran Khatri
# 1   I decided to support Doge as it felt like the ...     Pragya Swastik
# 2   Elon Musk tweets 'Wild $T1mes' after Tesla hit...     Pragya Swastik
# 3    How many years did it take for various compan...     Pragya Swastik
# 4   Which companies have $1 trillion or more marke...     Pragya Swastik
# 5   Policybazaar fixes price band for its IPO at ₹...        Hiral Goyal
# 6   BharatPe opposes PhonePe's trademarks for usin...       Kiran Khatri
# 7   Govt sends 202 notices to e-comm firms in a ye...     Pragya Swastik
# 8   India spending ₹8 lakh cr on petrol, diesel im...       Kiran Khatri
# 9   Crypto fund inflows hit record $1.5 bn as US B...  Aishwarya Awasthi
# 10  Govt to pitch to Tesla, Samsung for local batt...        Hiral Goyal
# 11  Nykaa shares trade at 60% premium in grey mark...        Hiral Goyal
# ...

# %%
categories = ['business',
           'sports',
           'technology',
           'entertainment']

# %%
# Create a function that takes a list of websites and parses the articles from them and creates a dictionary with 
# title and content of each article

def get_news_articles(categories):
    
    url = 'https://inshorts.com/en/read/'
    
    for category in categories:
        
        if category == categories[0]:
        
            response = requests.get(url+category, headers={'user-agent': 'Codeup DS Germain'})
            soup = BeautifulSoup(response.text)
        
            #Get the articles from the web page
            articles = soup.select('.news-card.z-depth-1')
        
            article = articles[0]
        
            df = pd.DataFrame([parse_article(article, category) for article in articles])   
            
        
        else: 
            
            response = requests.get(url+category, headers={'user-agent': 'Codeup DS Germain'})
            soup = BeautifulSoup(response.text)
        
            #Get the articles from the web page
            articles = soup.select('.news-card.z-depth-1')
        
            article = articles[0]  
            
            df = df.append(pd.DataFrame([parse_article(article, category) for article in articles]), ignore_index=True)
        
    return df

# %%
get_news_articles(categories)
# Out:
#                                                 title          author  \
# 0   India's Covaxin may get WHO approval in next 2...    Kiran Khatri
# 1   Which companies have $1 trillion or more marke...  Pragya Swastik
# 2   I decided to support Doge as it felt like the ...  Pragya Swastik
# 3   Elon Musk tweets 'Wild $T1mes' after Tesla hit...  Pragya Swastik
# 4    How many years did it take for various compan...  Pragya Swastik
# ..                                                ...             ...
# 95  It was 1 story for me: Kabir on not directing ...      Udit Gupta
# 96  Web is more streamlined and fair as compared t...      Udit Gupta
# 97  Wanted to be part of this family: Angelina on ...  Amartya Sharma
# 98  Maha CM to write to PM over Bollywood's portra...   Deepika Bhatt
# 99  It seems unreal: Adarsh on working with Meryl,...      Udit Gupta
#
#                                               content       category
# ...

# %%
import acquire

# %%
categories = ['business',
           'sports',
           'technology',
           'entertainment']

# %%
acquire.get_news_articles(categories)
# Out:
# /Users/vfirey/codeup-data-science/natural-language-processing-exercises/acquire.py:107: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 107 of the file /Users/vfirey/codeup-data-science/natural-language-processing-exercises/acquire.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   soup = BeautifulSoup(response.text)
# ...

# %%
urls = ['https://codeup.com/data-science/codeups-data-science-career-accelerator-is-here/',
        'https://codeup.com/data-science/data-science-myths/',
        'https://codeup.com/data-science/data-science-vs-data-analytics-whats-the-difference/',
        'https://codeup.com/data-science/10-tips-to-crush-it-at-the-sa-tech-job-fair/',
        'https://codeup.com/data-science/competitor-bootcamps-are-closing-is-the-model-in-danger/']

# %%
acquire.get_blog_articles(urls)
# Out:
# /Users/vfirey/codeup-data-science/natural-language-processing-exercises/acquire.py:39: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 39 of the file /Users/vfirey/codeup-data-science/natural-language-processing-exercises/acquire.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   soup = BeautifulSoup(response.text)
# ...
